# %%
def getHands(handData):
    playerCount = len(handData) - 1
    playerHands = []
    for player in playerCount:
        playerHands.append([handData[player][0], handData[player][1], (handData[-1][i] for i in handData[-1])])
    print(playerHands)

# %%
class HandType():
    HIGH_CARD = 1
    PAIR = 2
    TWO_PAIR = 3
    THREE_OF_A_KIND = 4
    STRAIGHT = 5
    FLUSH = 6
    FULL_HOUSE = 7
    FOUR_OF_A_KIND = 8
    STRAIGHT_FLUSH = 9

def evaluateHand(cards):
    pass

def compairHands(hands):
    pass

# %%
# take input as an array
# format: [[player 1 hole cards], [player2 hole cards], ... , [player-1 hole cards], [community cards]]
handData = [['K♥', 'J♠'], ['Q♦', '8♣'], ['9♥', '3♣'], ['5♦', '2♣', '9♦', '6♦', 'J♥']]
getHands(handData)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 # take input as an array
#       2 # format: [[player 1 hole cards], [player2 hole cards], ... , [player-1 hole cards], [community cards]]
#       3 handData = [['K♥', 'J♠'], ['Q♦', '8♣'], ['9♥', '3♣'], ['5♦', '2♣', '9♦', '6♦', 'J♥']]
# ----> 4 getHands(handData)
#
# Cell In[4], line 4, in getHands(handData)
#       2 playerCount = len(handData) - 1
#       3 playerHands = []
# ----> 4 for player in playerCount:
#       5     playerHands.append([handData[player][0], handData[player][1], (handData[-1][i] for i in handData[-1])])
#       6 print(playerHands)
#
# TypeError: 'int' object is not iterable
